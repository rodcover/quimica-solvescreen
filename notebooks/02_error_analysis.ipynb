# %% [markdown]
# # Análise de erros (ΔG bulk)
#
# 1. Treine com MNSOL processado (`data/processed/*.parquet`).
# 2. Gere predições no conjunto de teste e compare com rótulos.
# 3. Agrupe erros por família de solvente ou por clusters de fingerprint (RDKit) para inspeção qualitativa.
#
# Referência de métricas: Lim & Jung, *Chem. Sci.* **2019** (Delfos), [DOI 10.1039/C9SC02452B](https://doi.org/10.1039/C9SC02452B).

# %%
from pathlib import Path
import pandas as pd
import numpy as np

# Exemplo: carregar Parquet limpo e um modelo joblib (ajuste caminhos)
# df = pd.read_parquet(Path("../data/processed/mnsol_clean.parquet"))
# import joblib
# bundle = joblib.load(Path("../models/baseline.joblib"))
# from solvscreen.model_bundle import predict_bulk
# y_true = df["delta_g_kcal_mol"].values
# y_pred = [predict_bulk(bundle, s)[0] for s in df["smiles"]]
# err = np.array(y_pred) - y_true
# display(pd.Series(err).describe())
